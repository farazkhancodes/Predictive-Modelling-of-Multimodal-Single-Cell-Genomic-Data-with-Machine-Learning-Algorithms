# %% [markdown]
# # **FEATURE ENGINEERING AND DATA PREPARATION**

# %%
import warnings
warnings.simplefilter(action = 'ignore')
import numpy as np 
import pandas as pd 
import gc

# %%
from scipy.sparse import load_npz
train = load_npz("./Data/train_multi_inputs_values.sparse.npz")
train_index = np.load("./Data/train_multi_inputs_idxcol.npz", allow_pickle = True)
targets = load_npz("./Data/train_multi_targets_values.sparse.npz")
test = load_npz("./Data/test_multi_inputs_values.sparse.npz")
test_index = np.load("./Data/test_multi_inputs_idxcol.npz", allow_pickle = True)

# %%
meta_df = pd.read_csv('/kaggle/input/open-problems-multimodal/metadata.csv', index_col = 'cell_id')
meta_df = meta_df[meta_df.technology == 'multiome'].drop(columns = ['cell_type','technology'])
meta_df['gender'] = meta_df.donor.apply(lambda x : 1 if x != 13176 else 0)
meta_df
# Out:
#               day  donor  gender
# cell_id
# 458c2ae2c9b1    2  27678       1
# 01a0659b0710    2  27678       1
# 028a8bc3f2ba    2  27678       1
# 7ec0ca8bb863    2  27678       1
# caa0b0022cdc    2  27678       1
# ...           ...    ...     ...
# 96a60b026659   10  31800       1
# d493e546991e   10  31800       1
# 05666c99aa48   10  31800       1
# 121f946642b5   10  31800       1
# b847ba21f59f   10  31800       1
#
# [161877 rows x 3 columns]

# %%
from sklearn.decomposition import TruncatedSVD as tSVD
row_indices = np.arange(train.shape[0])
np.random.seed(42)
np.random.shuffle(row_indices)
row_indices = row_indices[:50000] # Selecting Only 50000 For Our Analysis
def transform(data, index, dimensions, filter = False):
    global meta_df, row_indices
    svd = tSVD(n_components = dimensions, random_state = 1)
    data = svd.fit_transform(data)
    print(f'- Reduced To {dimensions} Dimensions') 

    meta_data = meta_df.reindex(index)
    data = np.column_stack((data, meta_data))
    print('- Important Columns Added')
    
    if filter : data = data[row_indices]
    print('- 50000 Rows Selected Randomly')
    print(f"- Final Shape Of Data is {data.shape}")
    print("-"* 65)
    print()
    return data

# %%
DIMENSION = 15

print("-"*22, 'For Train Data', "-"*22)
train = transform(train, list(train_index['index']), DIMENSION, True)

print("-"*22, 'For Target Data', "-"*22)
targets = targets[row_indices]
print('- 50000 Rows Selected Randomly')
targets = targets.toarray()
print(f"- Final Shape Of Data is {targets.shape}")
print("-"* 65)
print()

test_index = list(test_index['index'])
meta_test = meta_df.reindex(test_index)

print("-"*22, 'For Donor Test Data', "-"*22)
donor_test_index = meta_test[(meta_test.day != 10) & (meta_test.donor == 27678)].index
indices = [i for i in range(len(donor_test_index)) if donor_test_index[i] in test_index]
donor_test = test[indices , : ]
donor_test = transform(donor_test, donor_test_index, DIMENSION)

print("-"*22, 'For Day Test Data', "-"*22)
day_test_index = meta_test[meta_test.day == 10].index
indices = [i for i in range(len(day_test_index)) if day_test_index[i] in test_index]
day_test = test[indices , : ]
day_test = transform(day_test, day_test_index, DIMENSION)

del train_index, test, test_index, donor_test_index, day_test_index, meta_df

gc.collect()
# Out:
# ---------------------- For Train Data ----------------------
# - Reduced To 15 Dimensions
# - Important Columns Added
# - 50000 Rows Selected Randomly
# - Final Shape Of Data is (50000, 18)
# -----------------------------------------------------------------
#
# ---------------------- For Target Data ----------------------
# - 50000 Rows Selected Randomly
# - Final Shape Of Data is (50000, 23418)
# -----------------------------------------------------------------
#
# ---------------------- For Donor Test Data ----------------------
# - Reduced To 15 Dimensions
# - Important Columns Added
# - 50000 Rows Selected Randomly
# - Final Shape Of Data is (24162, 18)
# -----------------------------------------------------------------
#
# ---------------------- For Day Test Data ----------------------
# - Reduced To 15 Dimensions
# - Important Columns Added
# - 50000 Rows Selected Randomly
# - Final Shape Of Data is (31773, 18)
# -----------------------------------------------------------------
# 22

# %%
# Saving The Clean Data
np.save('train', train)
np.save('targets', targets)
np.save('donor_test', donor_test)
np.save('day_test', day_test)

# %% [markdown]
# # **MODELLING**

# %%
# # Trun On The GPU And Run This (Not required if running locally)
# import warnings
# warnings.simplefilter(action = 'ignore')
# import numpy as np 
# import pandas as pd 
# import gc

# # Load The Data
# train = np.load('/kaggle/input/del-later/train.npy', allow_pickle = True)
# targets = np.load('/kaggle/input/del-later/targets.npy', allow_pickle = True)
# donor_test = np.load('/kaggle/input/del-later/donor_test.npy', allow_pickle = True)
# day_test = np.load('/kaggle/input/del-later/day_test.npy', allow_pickle = True)
# print(train.shape, targets.shape)

# %%
def correlation_score(y_true, y_hat):
    if type(y_true) == pd.DataFrame: y_true = y_true.values
    if type(y_hat) == pd.DataFrame: y_hat = y_hat.values
    corrsum = 0
    for i in range(len(y_true)):
        corrsum += np.corrcoef(y_true[i], y_hat[i])[1, 0]
    return corrsum / len(y_true)

# %%
from keras.models import Sequential
from keras.layers import Dense

net = Sequential()
net.add(Dense(50, input_dim = train.shape[1], activation='relu'))
net.add(Dense(50, activation='relu'))
net.add(Dense(targets.shape[1], activation='linear'))
net.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

EPOCHS = 20
BATCHES = 100

# %%
# KFold Grouped By Donor
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error
from colorama import Fore, Style


y_cols = targets.shape[1]
groups = train[ : , -2]

kf = GroupKFold(n_splits = 3)
score_list = []
for fold, (idx_tr, idx_va) in enumerate(kf.split(train, groups = groups)):
    print(Fore.CYAN + f'Training Fold {fold} with Donors {list(map(int, set(train[idx_tr][: , -2])))} for Donor {list(map(int, set(train[idx_va][: , -2])))}'+ Style.RESET_ALL)
    X_tr = train[idx_tr]
    y_tr = targets[:,: y_cols][idx_tr]
    X_va = train[idx_va]
    y_va = targets[:,: y_cols][idx_va]
   
    net.fit(X_tr, y_tr.copy(), epochs = EPOCHS, batch_size = BATCHES, validation_data = (X_va, y_va))
    y_hat = net.predict(X_va)
        
    del X_tr, y_tr
    gc.collect()

    # We validate the model (with mse and correlation)
    mse = mean_squared_error(y_va, y_hat)
    corrscore = correlation_score(y_va, y_hat)

    del X_va, y_va
    gc.collect()

    print(Fore.CYAN + f"Fold {fold} {train.shape[1]:4}: mse = {mse:.4f}, corr =  {corrscore:.4f}"+ Style.RESET_ALL)
    print()
    score_list.append((mse, corrscore))

# Averaging Scores From All The Folds
if len(score_list) > 1:
    result_df = pd.DataFrame(score_list, columns=['mse', 'corrscore'])
    print(Fore.YELLOW + f"Average MSE : {result_df.mse.mean():.4f}, Average Correlation : {result_df.corrscore.mean():.4f}"+ Style.RESET_ALL)
# Out:
# Training Fold 0 with Donors [13176, 32606] for Donor [31800]
# Epoch 1/20
# 328/328 [==============================] - 10s 18ms/step - loss: 196.7482 - mean_squared_error: 196.7482 - val_loss: 2.3297 - val_mean_squared_error: 2.3297
# Epoch 2/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.5355 - mean_squared_error: 2.5355 - val_loss: 2.4311 - val_mean_squared_error: 2.4311
# Epoch 3/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.5475 - mean_squared_error: 2.5475 - val_loss: 2.5382 - val_mean_squared_error: 2.5382
# Epoch 4/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.5584 - mean_squared_error: 2.5584 - val_loss: 2.8311 - val_mean_squared_error: 2.8311
# Epoch 5/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.5717 - mean_squared_error: 2.5717 - val_loss: 2.7601 - val_mean_squared_error: 2.7601
# Epoch 6/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.5892 - mean_squared_error: 2.5892 - val_loss: 2.8715 - val_mean_squared_error: 2.8715
# Epoch 7/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.6088 - mean_squared_error: 2.6088 - val_loss: 3.0575 - val_mean_squared_error: 3.0575
# Epoch 8/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.6260 - mean_squared_error: 2.6260 - val_loss: 3.2077 - val_mean_squared_error: 3.2077
# Epoch 9/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.6369 - mean_squared_error: 2.6369 - val_loss: 3.2847 - val_mean_squared_error: 3.2847
# Epoch 10/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.6301 - mean_squared_error: 2.6301 - val_loss: 3.3512 - val_mean_squared_error: 3.3512
# Epoch 11/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.6278 - mean_squared_error: 2.6278 - val_loss: 3.8134 - val_mean_squared_error: 3.8134
# Epoch 12/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.5923 - mean_squared_error: 2.5923 - val_loss: 3.3220 - val_mean_squared_error: 3.3220
# Epoch 13/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.5329 - mean_squared_error: 2.5329 - val_loss: 3.2345 - val_mean_squared_error: 3.2345
# Epoch 14/20
# 328/328 [==============================] - 3s 8ms/step - loss: 2.4862 - mean_squared_error: 2.4862 - val_loss: 3.0661 - val_mean_squared_error: 3.0661
# Epoch 15/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.4202 - mean_squared_error: 2.4202 - val_loss: 2.6726 - val_mean_squared_error: 2.6726
# Epoch 16/20
# 328/328 [==============================] - 3s 9ms/step - loss: 2.3472 - mean_squared_error: 2.3472 - val_loss: 2.5376 - val_mean_squared_error: 2.5376
# Epoch 17/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.0875 - mean_squared_error: 2.0875 - val_loss: 2.8551 - val_mean_squared_error: 2.8551
# Epoch 12/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1814 - mean_squared_error: 2.1814 - val_loss: 2.1280 - val_mean_squared_error: 2.1280
# Epoch 13/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1423 - mean_squared_error: 2.1423 - val_loss: 2.1368 - val_mean_squared_error: 2.1368
# Epoch 14/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1351 - mean_squared_error: 2.1351 - val_loss: 2.2919 - val_mean_squared_error: 2.2919
# Epoch 15/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1320 - mean_squared_error: 2.1320 - val_loss: 2.2824 - val_mean_squared_error: 2.2824
# Epoch 16/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1325 - mean_squared_error: 2.1325 - val_loss: 2.1465 - val_mean_squared_error: 2.1465
# Epoch 17/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1308 - mean_squared_error: 2.1308 - val_loss: 2.1156 - val_mean_squared_error: 2.1156
# Epoch 18/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1305 - mean_squared_error: 2.1305 - val_loss: 2.1272 - val_mean_squared_error: 2.1272
# Epoch 19/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1281 - mean_squared_error: 2.1281 - val_loss: 2.1117 - val_mean_squared_error: 2.1117
# Epoch 20/20
# 343/343 [==============================] - 3s 8ms/step - loss: 2.1267 - mean_squared_error: 2.1267 - val_loss: 2.1090 - val_mean_squared_error: 2.1090
# 494/494 [==============================] - 1s 1ms/step
# Fold 2   18: mse = 2.1090, corr =  0.6428
#
# Average MSE : 2.1931, Average Correlation : 0.6431

# %%
# KFold Grouped By Day
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error

y_cols = targets.shape[1]
groups = train[ : , -3]

kf = GroupKFold(n_splits = 4)
score_list = []
for fold, (idx_tr, idx_va) in enumerate(kf.split(train, groups = groups)):
    print(Fore.CYAN + f'Training Fold {fold} with Day {list(map(int, set(train[idx_tr][: , -3])))} for Day {list(map(int, set(train[idx_va][: , -3])))}'+ Style.RESET_ALL)
    X_tr = train[idx_tr]
    y_tr = targets[:,: y_cols][idx_tr]
    X_va = train[idx_va]
    y_va = targets[:,: y_cols][idx_va]
   
    net.fit(X_tr, y_tr.copy(), epochs = EPOCHS, batch_size = BATCHES, validation_data = (X_va, y_va))
    y_hat = net.predict(X_va)
        
    del X_tr, y_tr
    gc.collect()

    # We validate the model (with mse and correlation)
    mse = mean_squared_error(y_va, y_hat)
    corrscore = correlation_score(y_va, y_hat)

    del X_va, y_va
    gc.collect()

    print(Fore.CYAN + f"Fold {fold} {train.shape[1]:4}: mse = {mse:.4f}, corr =  {corrscore:.4f}"+ Style.RESET_ALL)
    print()
    score_list.append((mse, corrscore))

# Averaging Scores From All The Folds
if len(score_list) > 1:
    result_df = pd.DataFrame(score_list, columns=['mse', 'corrscore'])
# Epoch 15/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1107 - mean_squared_error: 2.1107 - val_loss: 2.1457 - val_mean_squared_error: 2.1457
# Epoch 16/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1086 - mean_squared_error: 2.1086 - val_loss: 2.1287 - val_mean_squared_error: 2.1287
# Epoch 17/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1084 - mean_squared_error: 2.1084 - val_loss: 2.1346 - val_mean_squared_error: 2.1346
# Epoch 18/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1093 - mean_squared_error: 2.1093 - val_loss: 2.1467 - val_mean_squared_error: 2.1467
# Epoch 19/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1096 - mean_squared_error: 2.1096 - val_loss: 2.1419 - val_mean_squared_error: 2.1419
# Epoch 20/20
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1095 - mean_squared_error: 2.1095 - val_loss: 2.1262 - val_mean_squared_error: 2.1262
# 421/421 [==============================] - 1s 1ms/step
# Fold 1   18: mse = 2.1262, corr =  0.6481
#
# Training Fold 2 with Day [3, 4, 7] for Day [2]
# Epoch 1/20
# 386/386 [==============================] - 5s 13ms/step - loss: 2.1246 - mean_squared_error: 2.1246 - val_loss: 2.1012 - val_mean_squared_error: 2.1012
# Epoch 2/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1232 - mean_squared_error: 2.1232 - val_loss: 2.1013 - val_mean_squared_error: 2.1013
# Epoch 3/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1242 - mean_squared_error: 2.1242 - val_loss: 2.1137 - val_mean_squared_error: 2.1137
# Epoch 4/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1305 - mean_squared_error: 2.1305 - val_loss: 2.1017 - val_mean_squared_error: 2.1017
# Epoch 5/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1229 - mean_squared_error: 2.1229 - val_loss: 2.1046 - val_mean_squared_error: 2.1046
# Epoch 6/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1235 - mean_squared_error: 2.1235 - val_loss: 2.1023 - val_mean_squared_error: 2.1023
# Epoch 7/20
# 386/386 [==============================] - 3s 8ms/step - loss: 2.1234 - mean_squared_error: 2.1234 - val_loss: 2.1089 - val_mean_squared_error: 2.1089
# Epoch 8/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1242 - mean_squared_error: 2.1242 - val_loss: 2.1022 - val_mean_squared_error: 2.1022
# Epoch 9/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1234 - mean_squared_error: 2.1234 - val_loss: 2.1103 - val_mean_squared_error: 2.1103
# Epoch 10/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1227 - mean_squared_error: 2.1227 - val_loss: 2.1059 - val_mean_squared_error: 2.1059
# Epoch 11/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1236 - mean_squared_error: 2.1236 - val_loss: 2.1125 - val_mean_squared_error: 2.1125
# Epoch 12/20
# 386/386 [==============================] - 3s 8ms/step - loss: 2.1242 - mean_squared_error: 2.1242 - val_loss: 2.1021 - val_mean_squared_error: 2.1021
# Epoch 13/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1236 - mean_squared_error: 2.1236 - val_loss: 2.1071 - val_mean_squared_error: 2.1071
# Epoch 14/20
# 386/386 [==============================] - 3s 8ms/step - loss: 2.1245 - mean_squared_error: 2.1245 - val_loss: 2.1063 - val_mean_squared_error: 2.1063
# Epoch 15/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1228 - mean_squared_error: 2.1228 - val_loss: 2.1182 - val_mean_squared_error: 2.1182
# Epoch 16/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1232 - mean_squared_error: 2.1232 - val_loss: 2.1075 - val_mean_squared_error: 2.1075
# Epoch 17/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1239 - mean_squared_error: 2.1239 - val_loss: 2.1124 - val_mean_squared_error: 2.1124
# Epoch 18/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1227 - mean_squared_error: 2.1227 - val_loss: 2.1047 - val_mean_squared_error: 2.1047
# Epoch 19/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1224 - mean_squared_error: 2.1224 - val_loss: 2.0990 - val_mean_squared_error: 2.0990
# Epoch 20/20
# 386/386 [==============================] - 3s 7ms/step - loss: 2.1229 - mean_squared_error: 2.1229 - val_loss: 2.1087 - val_mean_squared_error: 2.1087
# 357/357 [==============================] - 0s 1ms/step
# Fold 2   18: mse = 2.1087, corr =  0.6549
#
# Training Fold 3 with Day [2, 3, 4] for Day [7]
# Epoch 1/20
# 395/395 [==============================] - 5s 12ms/step - loss: 2.0989 - mean_squared_error: 2.0989 - val_loss: 2.1744 - val_mean_squared_error: 2.1744
# Epoch 2/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0969 - mean_squared_error: 2.0969 - val_loss: 2.1897 - val_mean_squared_error: 2.1897
# Epoch 3/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0950 - mean_squared_error: 2.0950 - val_loss: 2.2018 - val_mean_squared_error: 2.2018
# Epoch 4/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0946 - mean_squared_error: 2.0946 - val_loss: 2.2018 - val_mean_squared_error: 2.2018
# Epoch 5/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0930 - mean_squared_error: 2.0930 - val_loss: 2.2053 - val_mean_squared_error: 2.2053
# Epoch 6/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0921 - mean_squared_error: 2.0921 - val_loss: 2.2155 - val_mean_squared_error: 2.2155
# Epoch 7/20
# 395/395 [==============================] - 3s 8ms/step - loss: 2.0920 - mean_squared_error: 2.0920 - val_loss: 2.2252 - val_mean_squared_error: 2.2252
# Epoch 8/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0915 - mean_squared_error: 2.0915 - val_loss: 2.2274 - val_mean_squared_error: 2.2274
# Epoch 9/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0904 - mean_squared_error: 2.0904 - val_loss: 2.2378 - val_mean_squared_error: 2.2378
# Epoch 10/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0906 - mean_squared_error: 2.0906 - val_loss: 2.2393 - val_mean_squared_error: 2.2393
# Epoch 11/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0901 - mean_squared_error: 2.0901 - val_loss: 2.2442 - val_mean_squared_error: 2.2442
# Epoch 12/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0898 - mean_squared_error: 2.0898 - val_loss: 2.2513 - val_mean_squared_error: 2.2513
# Epoch 13/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0901 - mean_squared_error: 2.0901 - val_loss: 2.2510 - val_mean_squared_error: 2.2510
# Epoch 14/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0895 - mean_squared_error: 2.0895 - val_loss: 2.2556 - val_mean_squared_error: 2.2556
# Epoch 15/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0901 - mean_squared_error: 2.0901 - val_loss: 2.2596 - val_mean_squared_error: 2.2596
# Epoch 16/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0888 - mean_squared_error: 2.0888 - val_loss: 2.2665 - val_mean_squared_error: 2.2665
# Epoch 17/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0902 - mean_squared_error: 2.0902 - val_loss: 2.2625 - val_mean_squared_error: 2.2625
# Epoch 18/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0902 - mean_squared_error: 2.0902 - val_loss: 2.2647 - val_mean_squared_error: 2.2647
# Epoch 19/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0898 - mean_squared_error: 2.0898 - val_loss: 2.2760 - val_mean_squared_error: 2.2760
# Epoch 20/20
# 395/395 [==============================] - 3s 7ms/step - loss: 2.0901 - mean_squared_error: 2.0901 - val_loss: 2.2672 - val_mean_squared_error: 2.2672
# 329/329 [==============================] - 0s 1ms/step
# Fold 3   18: mse = 2.2672, corr =  0.5717
#
# Average MSE : 2.1625, Average Correlation : 0.6349

# %%
# Retraining On Whole Data
net.fit(train, targets, epochs = EPOCHS, batch_size = BATCHES)
print(mean_squared_error(targets, net.predict(train)), correlation_score(targets, net.predict(train)))
print('Donor Test Prediction :/n', net.predict(donor_test))
print('Day Test Prediction :/n', net.predict(day_test))
# Out:
# Epoch 1/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1229 - mean_squared_error: 2.1229
# Epoch 2/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1203 - mean_squared_error: 2.1203
# Epoch 3/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1187 - mean_squared_error: 2.1187
# Epoch 4/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1173 - mean_squared_error: 2.1173
# Epoch 5/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1157 - mean_squared_error: 2.1157
# Epoch 6/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1160 - mean_squared_error: 2.1160
# Epoch 7/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1153 - mean_squared_error: 2.1153
# Epoch 8/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1147 - mean_squared_error: 2.1147
# Epoch 9/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1147 - mean_squared_error: 2.1147
# Epoch 10/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1160 - mean_squared_error: 2.1160
# Epoch 11/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1138 - mean_squared_error: 2.1138
# Epoch 12/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1126 - mean_squared_error: 2.1126
# Epoch 13/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1141 - mean_squared_error: 2.1141
# Epoch 14/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1135 - mean_squared_error: 2.1135
# Epoch 15/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1124 - mean_squared_error: 2.1124
# Epoch 16/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1142 - mean_squared_error: 2.1142
# Epoch 17/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1129 - mean_squared_error: 2.1129
# Epoch 18/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1131 - mean_squared_error: 2.1131
# Epoch 19/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1127 - mean_squared_error: 2.1127
# Epoch 20/20
# 500/500 [==============================] - 3s 6ms/step - loss: 2.1118 - mean_squared_error: 2.1118
# 1563/1563 [==============================] - 2s 1ms/step
# 1563/1563 [==============================] - 2s 1ms/step
# 2.1087084 0.6460690431040537
# 756/756 [==============================] - 1s 1ms/step
# Donor Test Prediction :/n [[0.60391665 0.3637505  0.24038602 ... 1.2372355  1.3559195  2.1369023 ]
#  [0.5108135  0.34656546 0.30472034 ... 1.1135321  1.2038752  2.0147128 ]
#  [0.5569416  0.35507983 0.27284575 ... 1.1748211  1.2792058  2.075252  ]
#  ...
#  [0.5384964  0.35167518 0.28559142 ... 1.1503135  1.2490835  2.0510442 ]
#  [0.37314346 0.32115424 0.39985037 ... 0.93061405 0.9790502  1.8340335 ]
#  [0.68102175 0.37798262 0.18710636 ... 1.3396828  1.4818376  2.238096  ]]
# 993/993 [==============================] - 1s 1ms/step
# Day Test Prediction :/n [[0.3855572  0.32344556 0.3912725  ... 0.9471078  0.9993227  1.8503253 ]
#  [0.36262494 0.3192127  0.40711868 ... 0.9166384  0.9618727  1.8202288 ]
#  [0.36262494 0.3192127  0.40711868 ... 0.9166384  0.9618727  1.8202288 ]
#  ...
#  [0.472293   0.3394553  0.33133802 ... 1.062351   1.1409686  1.9641583 ]
#  [0.36262494 0.3192127  0.40711868 ... 0.9166384  0.9618727  1.8202288 ]
#  [0.36262494 0.3192127  0.40711868 ... 0.9166384  0.9618727  1.8202288 ]]

# %% [markdown]
# ----------------
